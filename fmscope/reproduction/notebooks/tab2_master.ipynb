# %% [markdown]
# # Paper Table 2 — master BA results
#
# Thin orchestrator around `fmscope.paper.*`. Output landing
# directory is `paper_figures/` by default — override with
# `FMSCOPE_OUTPUT_DIR`.

# %%
import os
from pathlib import Path

# Optional: redirect output to a scratch dir.
# os.environ['FMSCOPE_OUTPUT_DIR'] = '/tmp/fmscope_demo'
out = Path(os.environ.get('FMSCOPE_OUTPUT_DIR', 'paper_figures'))
out.mkdir(exist_ok=True, parents=True)
print(f'output dir: {out.resolve()}')

# %%
from reproduction.builders import tab1_master
tab1_master.main()

# %% [markdown]
# ## Expected artifacts

# %%
expected = ['master_results_table.md', 'table2_master_performance.tex']
for f in expected:
    p = out / f
    status = 'OK' if p.exists() else 'MISSING'
    print(f'  [{status}] {p}')
